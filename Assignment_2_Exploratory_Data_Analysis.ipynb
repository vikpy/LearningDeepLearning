# %% [markdown]
# <a href="https://colab.research.google.com/github/vikpy/DLSem3/blob/master/Assignment_2_Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classwork Assignment

# %% [markdown]
# #Exercise 2

# %%
df = pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv")
df.head()
# Out:
#    symboling  normalized-losses         make  ... horsepower-binned diesel gas
# 0          3                122  alfa-romero  ...            Medium      0   1
# 1          3                122  alfa-romero  ...            Medium      0   1
# 2          1                122  alfa-romero  ...            Medium      0   1
# 3          2                164         audi  ...            Medium      0   1
# 4          2                164         audi  ...            Medium      0   1
#
# [5 rows x 29 columns]

# %%
print('*'*100)
print("Shape")
print(df.shape)
print('*'*100)
print("Data Types")
print(df.dtypes)
print('*'*100)
# Out:
# ****************************************************************************************************
# Shape
# (201, 29)
# ****************************************************************************************************
# Data Types
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# ...

# %%
# Columns with positive correlations
df.corr()["price"][ df.corr()["price"] > 0]
# Out:
# normalized-losses    0.133999
# wheel-base           0.584642
# length               0.690628
# width                0.751265
# height               0.135486
# curb-weight          0.834415
# engine-size          0.872335
# bore                 0.543155
# stroke               0.082310
# compression-ratio    0.071107
# horsepower           0.809575
# price                1.000000
# city-L/100km         0.789898
# diesel               0.110326
# Name: price, dtype: float64

# %%
# Columns with negative correlations
df.corr()["price"][ df.corr()["price"] < 0]
# Out:
# symboling     -0.082391
# peak-rpm      -0.101616
# city-mpg      -0.686571
# highway-mpg   -0.704692
# gas           -0.110326
# Name: price, dtype: float64

# %%
df.dtypes["peak-rpm"]
# Out:
# dtype('float64')

# %%
sns.regplot(df["engine-size"], df["price"], color='g')

# %% [markdown]
# From the plot we can see that price positively depends on the engine size. Relation seems fairly linear from the data.

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
# Checking for symboling
sns.regplot(df["symboling"], df["price"], color='g')

# %% [markdown]
# Symbolling does not affect that much

# %%
sns.regplot(df["normalized-losses"], df["price"], color='g')

# %% [markdown]
# normalized losses also does not affect the price that much

# %%
sns.regplot(df["wheel-base"], df["price"], color='g')

# %% [markdown]
# Wheel base has a fairly linear relationship with price.

# %%
sns.regplot(df["length"], df["price"], color='g')

# %% [markdown]
# Length has a fairly linear relationship with the price.

# %%
sns.regplot(df["width"], df["price"], color='g')

# %% [markdown]
# Width has relation as well.

# %%
sns.regplot(df["height"], df["price"], color='g')

# %% [markdown]
# Height has a fairly linear. Not very linear

# %%
sns.regplot(df["curb-weight"], df["price"], color='g')

# %% [markdown]
# It has strong positive and linear relationship with price.

# %% [markdown]
# We will check for following columns now
#
# bore                 float64
#
# stroke               float64
#
# compression-ratio    float64
#
# horsepower           float64
#
# peak-rpm             float64
#
# highway-mpg            int64
#
# city-L/100km         float64
#
# diesel                 int64
#
# gas                    int64

# %%
sns.regplot(df["bore"], df["price"], color='g')

# %%
sns.regplot(df["stroke"], df["price"], color='g')

# %%
sns.regplot(df["compression-ratio"], df["price"], color='g')

# %%
sns.regplot(df["horsepower"], df["price"], color='g')

# %%
sns.regplot(df["peak-rpm"], df["price"], color='g')

# %%
sns.regplot(df["highway-mpg"], df["price"], color='g')

# %%
sns.regplot(df["city-L/100km"], df["price"], color='g')

# %%
sns.regplot(df["diesel"], df["price"], color='g')

# %%
sns.regplot(df["gas"], df["price"], color="g")

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr() )

# %%
sns.boxplot(x=df["body-style"], y=df["price"])

# %%
df.dtypes.reset_index()[df.dtypes.reset_index()[0] == "object"]["index"]
# Out:
# 2                  make
# 3            aspiration
# 4          num-of-doors
# 5            body-style
# 6          drive-wheels
# 7       engine-location
# 13          engine-type
# 14     num-of-cylinders
# 16          fuel-system
# 26    horsepower-binned
# Name: index, dtype: object

# %%
fig_dims = (50, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x=df["make"], y=df["price"], ax=ax)

# %%
#fig_dims = (50, 20)
#fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x=df["aspiration"], y=df["price"])

# %%
sns.boxplot(x=df["num-of-doors"], y=df["price"])

# %%
sns.boxplot(x=df["drive-wheels"], y=df["price"])

# %%
sns.boxplot(x=df["engine-location"], y=df["price"])

# %%
sns.boxplot(x=df["engine-type"], y=df["price"])

# %%
sns.boxplot(x=df["num-of-cylinders"], y=df["price"])

# %%
sns.boxplot(x=df["fuel-system"], y=df["price"])

# %%
sns.boxplot(x=df["horsepower-binned"], y=df["price"])

# %% [markdown]
# From the boxblots we can find out categories which will have the maximum number of outliers

# %% [markdown]
# Descriptive Statistics of Numeric variables is as follows

# %%
df[list(df.dtypes.reset_index()[df.dtypes.reset_index()[0] != "object"]["index"]) ].describe()
# Out:
#         symboling  normalized-losses  ...      diesel         gas
# count  201.000000          201.00000  ...  201.000000  201.000000
# mean     0.840796          122.00000  ...    0.099502    0.900498
# std      1.254802           31.99625  ...    0.300083    0.300083
# min     -2.000000           65.00000  ...    0.000000    0.000000
# 25%      0.000000          101.00000  ...    0.000000    1.000000
# 50%      1.000000          122.00000  ...    0.000000    1.000000
# 75%      2.000000          137.00000  ...    0.000000    1.000000
# max      3.000000          256.00000  ...    1.000000    1.000000
#
# [8 rows x 19 columns]

# %% [markdown]
# Descriptive Statistics of Categorical Variables

# %%
df[list(df.dtypes.reset_index()[df.dtypes.reset_index()[0] == "object"]["index"]) ].describe()
# Out:
#           make aspiration  ... fuel-system horsepower-binned
# count      201        201  ...         201               200
# unique      22          2  ...           8                 3
# top     toyota        std  ...        mpfi               Low
# freq        32        165  ...          92               115
#
# [4 rows x 10 columns]

# %%
df[list(df.dtypes.reset_index()[df.dtypes.reset_index()[0] == "object"]["index"]) ].count()
# Out:
# make                 201
# aspiration           201
# num-of-doors         201
# body-style           201
# drive-wheels         201
# engine-location      201
# engine-type          201
# num-of-cylinders     201
# fuel-system          201
# horsepower-binned    200
# dtype: int64

# %%
df.reset_index()[["make", "index"] ].groupby("make").count().sort_values(by="index", ascending=False)
# Out:
#                index
# make
# toyota            32
# nissan            18
# mazda             17
# mitsubishi        13
# honda             13
# volkswagen        12
# subaru            12
# peugot            11
# volvo             11
# dodge              9
# mercedes-benz      8
# bmw                8
# plymouth           7
# audi               6
# saab               6
# porsche            4
# jaguar             3
# chevrolet          3
# alfa-romero        3
# isuzu              2
# renault            2
# mercury            1

# %%
df.reset_index()[["aspiration", "index"] ].groupby("aspiration").count().sort_values(by="index", ascending=False)
# Out:
#             index
# aspiration
# std           165
# turbo          36

# %%
df.reset_index()[["num-of-doors", "index"] ].groupby("num-of-doors").count().sort_values(by="index", ascending=False)
# Out:
#               index
# num-of-doors
# four            115
# two              86

# %%
df.reset_index()[["body-style", "index"] ].groupby("body-style").count().sort_values(by="index", ascending=False)
# Out:
#              index
# body-style
# sedan           94
# hatchback       68
# wagon           25
# hardtop          8
# convertible      6

# %%
df.reset_index()[["drive-wheels", "index"] ].groupby("drive-wheels").count().sort_values(by="index", ascending=False)
# Out:
#               index
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
engine-location      201
engine-type          201
num-of-cylinders     201
fuel-system          201
horsepower-binned    200

# %%
df.reset_index()[["engine-location", "index"] ].groupby("engine-location").count().sort_values(by="index", ascending=False)
# Out:
#                  index
# engine-location
# front              198
# rear                 3

# %%
df.reset_index()[["engine-type", "index"] ].groupby("engine-type").count().sort_values(by="index", ascending=False)
# Out:
#              index
# engine-type
# ohc            145
# ohcf            15
# ohcv            13
# dohc            12
# l               12
# rotor            4

# %%
df.reset_index()[["num-of-cylinders", "index"] ].groupby("num-of-cylinders").count().sort_values(by="index", ascending=False)
# Out:
#                   index
# num-of-cylinders
# four                157
# six                  24
# five                 10
# eight                 4
# two                   4
# three                 1
# twelve                1

# %%
df.reset_index()[["fuel-system", "index"] ].groupby("fuel-system").count().sort_values(by="index", ascending=False)
# Out:
#              index
# fuel-system
# mpfi            92
# 2bbl            64
# idi             20
# 1bbl            11
# spdi             9
# 4bbl             3
# mfi              1
# spfi             1

# %%
df.reset_index()[["horsepower-binned", "index"] ].groupby("horsepower-binned").count().sort_values(by="index", ascending=False)
# Out:
#                    index
# horsepower-binned
# Low                  115
# Medium                62
# High                  23

# %%
df[["drive-wheels", "price"]].groupby("drive-wheels").mean()
# Out:
#                      price
# drive-wheels
# 4wd           10241.000000
# fwd            9244.779661
# rwd           19757.613333
